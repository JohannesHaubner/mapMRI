# %%
import numpy as np
import pathlib
import matplotlib.pyplot as plt

# %%
path = pathlib.Path("/home/bastian/D1/registration/affine_croppedmriregistration_outputs/441848/E100A0.01LBFGS10C5/")

# %%
r1 = np.load(path / "normalized_residual0.npy")
r31 = np.load(path / "normalized_residual31.npy")

# %%
xmin, xmax = -200, 200

# %%
plt.hist(r1, bins=50)
plt.xlim(xmin, xmax)
plt.ylim(1e0, 1e7)
plt.yscale("log")
plt.figure()
plt.hist(r31, bins=50)
plt.xlim(xmin, xmax)
plt.ylim(1e0, 1e7)
plt.yscale("log")
plt.show()

# %%
loss = np.genfromtxt(path / "loss.txt", delimiter=",")
l2loss = np.genfromtxt(path / "l2loss.txt", delimiter=",")

# %%
plt.plot(loss, label="loss")
plt.plot(l2loss, label="L2loss")
plt.legend()

# %%
from dgregister.tukey import tukey

# %%
x = np.linspace(-1.5,1.5, 100)

# %%
plt.plot(x, tukey(x, c=1))
plt.plot(x, x**2)

# %%
print((r31**2).sum())
print((tukey(r31)**2).sum())
# Out:
# 13838.094599303186
# 11275.71555119118
